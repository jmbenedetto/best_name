# %%
import pandas as pd

# %%
df=pd.read_csv('tests/eval_files.csv', sep=';')
df
# Out:
#         original_file                                 human_defined_name
# 0    test_file_01.png  20250623_Ideativa_Receipt paid by Ideativa to ...
# 1    test_file_02.pdf  20250620_Ideativa_Tax Ideativa Work INSS and I...
# 2   test_file_03.xlsx  20250907_SCM_Inventory policy example workbook...
# 3    test_file_04.pdf  20250722_MyFinance_Receipt Paypal jmbenedetto ...
# 4    test_file_05.pdf  20250701_Relex_Ferreira Costa Presentation sup...
# 5    test_file_06.pdf  20250623_MyFinance_Receipt_Itau Joao Miguel pa...
# 6   test_file_07.pptx  20250601_Relex_RELEX Demand Planning and Sensi...
# 7    test_file_08.pdf  20240321_RoverAi_DKT DKT Forward project kick ...
# 8   test_file_09.docx  20250604_MyProperties_Power of attoerney from ...
# 9    test_file_10.jpg  20250907_MyFamily_Amelie Dra Patricia Lab exam...
# 10    test_file_11.py  20250907_MyProductivity_Convert LogSeq md into...
# 11   test_file_12.pdf  20250610_MyFinance_Invoice kingHost to Joao Mi...
# ...
